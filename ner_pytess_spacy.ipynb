# %%
from pdf2image import convert_from_path
import pytesseract
from PIL import Image
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
import de_core_news_sm
#spacy.load('de_core_news_sm')
nlp_de = spacy.load('de_core_news_sm') #German
nlp_en = en_core_web_sm.load() #English 
#image_to_string: pytesseract.pytesseract.tesseract_cmd = r'C:\Users\USER\AppData\Local\Tesseract-OCR\tesseract.exe'
#pytesseract.pytesseract.tesseract_cmd = 'C:\Program Files\Tesseract-OCR\tessdata'

#pytesseract.pytesseract.tesseract_cmd = 'C:\Program Files\Tesseract-OCR\tesseract.exe'  # your path may be different
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
pages = convert_from_path(r'C:\Users\jagadesh\Jupyter Projects\OCR\fwusecaseextractnamesfromtext\3.pdf', 500)

text=''
for page in pages:
    text = text + (pytesseract.image_to_string(page))

# %%
doc=nlp_en(text)

# %%
doc2=nlp_de(text)

# %%
# For checking
for X in doc.ents:
        print(X.text,X.label_)
# Out:
# 4 CARDINAL
# Robert Bosch PERSON
# 25 DATE
# 39006 DATE
# Magedeburg GPE
# LanterstraBe PERSON
# 19008551 DATE
# 310960 DATE
# Kunden- PERSON
# PRA ORG
# 310960 CARDINAL
# Robert Bosch PERSON
# 16 25 CARDINAL
# Fallig am 28/12/2019 ORG
# 39006 DATE
# Magedeburg GPE
# Zahlungsmittel Auf Rechnung
#  PERSON
# 4000 4000 939555 DATE
# Auftraggeber Lieferanschrift PERSON
# 310960 ORG
# Robert Bosch PERSON
# 322974 CARDINAL
# Robert Bosch PERSON
# 16 25 CARDINAL
# C/AGA ORG
# 39006 DATE
# Magedeburg GPE
# 71 DATE
# 10627 DATE
# Artikelnr Bezeichnung PERSON
# Einzelpreis Gesamtpreis Mwst PERSON
# 19006153 DATE
# SR - 30/05/2019 Ihre Beste EVENT
# Einmalige Wartung PERSON
# Auflistung PERSON
# Anlagen Nr PERSON
# Standort Bezeichnung Betriebsdauer PERSON
# NZBVE ORG
# 3h CARDINAL
# 3.0 CARDINAL
# NZBVE ORG
# UG ORG
# 24/036 CARDINAL
# 2279 MONEY
# UG NV2 ORG
# 92348 CARDINAL
# 24/036 CARDINAL
# 92354 1.0 CARDINAL
# 1h CARDINAL
# 92353 DATE
# OrderningCenter DE Abteilung ORG
# GS GPE
# 0391 5908182 CARDINAL
# / Fax: 0711 81155894 / PRODUCT
# Frau Filipchuk PERSON
# 030 CARDINAL
# 32788 205 PRODUCT
# Termin GPE
# Techniker PERSON
# S. Thormeier PERSON
# NR ORG
# 350,00 190 % PERCENT
# 99934 DATE
# Geschaftsfithrer ORG
# Thomas Buhren PERSON
# Graziano Beghelli PERSON
# HRB 22348 DATE
# Amtsgericht Duisburg PERSON
# Anschrift PERSON
# LanterstraBe PERSON
# +49 PERSON
# 2064 DATE
# Bankverbindung / Bank Information Steuernummer / Tax Number ORG
# Bayer PERSON
# Vereinsbank 101/5701/1496 FAC
# 709 CARDINAL
# UST-ID / VAT-ID ORG
# IBAN ORG
# BIC ORG
# 310960 CARDINAL
# Robert Bosch PERSON
# 25 CARDINAL
# 39006 CARDINAL
# Magedeburg GPE
# 19008551 DATE
# 310960 CARDINAL
# SA ORG
# 310960 DATE
# Robert Bosch PERSON
# 16 25 CARDINAL
# Zahlungsmittel Auf Rechnung
# Deutschland Zahlungsbedingung PERSON
# Lieferbedingung EW ORG
# Wahrung EUR PERSON
# Auftraggeber Lieferanschrift PERSON
# Robert Bosch PERSON
# 322974 CARDINAL
# Robert Bosch PERSON
# 16 25 CARDINAL
# C/AGA ORG
# 39006 DATE
# Magedeburg GPE
# 71 DATE
# 10627 DATE
# Artikelnr Bezeichnung PERSON
# Einzelpreis Gesamtpreis Mwst PERSON
# Sicuro PERSON
# 1,00 ORG
# NR ORG
# 350,00 190 % PERCENT
# 99934 DATE
# 190 % PERCENT
# 99934 DATE
# NR ORG
# 350,00 190 % PERCENT
# 99934 DATE
# 190 % PERCENT
# 99934 DATE
# NZBVE ORG
# 3h PRODUCT
# 190 % PERCENT
# 99931 DATE
# Wartung PERSON
# Das Lieferscheindatum PERSON
# Leistungsdatum PERSON
# EUR ORG
# Nettowarenwert MwSt PERSON
# Mehrwertsteuer PERSON
# EUR ORG
# 190 % PERCENT
# Thomas Buhren PERSON
# Graziano Beghelli PERSON
# HRB 22348 DATE
# Amtsgericht Duisburg PERSON
# Anschrift PERSON
# LanterstraBe PERSON
# +49 PERSON
# 2064 DATE
# Bankverbindung / Bank Information ORG
# Bayer PERSON
# Vereinsbank GPE
# BLZ ORG
# 20190 DATE
# 709 CARDINAL
# IBAN ORG
# 0637 09 DATE
# Steuernummer / Tax Number ORG
# UST-ID / VAT-ID ORG
# DE119062102 PRODUCT
# 2 CARDINAL
# 19008551 DATE
# 310960 CARDINAL
# Robert Bosch GmbH Kunden PERSON
# 310960 DATE
# 25 CARDINAL
# 39006 DATE
# Magedeburg GPE
# Beghelli PRAZISA PERSON
# LA ISA ORG
# Robert Bosch PERSON
# 16 25 CARDINAL
# Zahlungsmittel Auf Rechnung
# Deutschland Zahlungsbedingung PERSON
# Lieferbedingung EW ORG
# Wahrung EUR PERSON
# Auftraggeber Lieferanschrift PERSON
# Robert Bosch PERSON
# 322974 CARDINAL
# Robert Bosch PERSON
# 16 25 CARDINAL
# C/AGA ORG
# 39006 DATE
# Magedeburg GPE
# 71 DATE
# 10627 DATE
# Artikelnr Bezeichnung PERSON
# Einzelpreis Gesamtpreis Mwst PERSON
# Gesamtsumme PERSON
# Anschrift PERSON
# Thomas Buhren PERSON
# Graziano Beghelli LanterstraBe PERSON
# Vereinsbank GPE
# 709 CARDINAL
# UST-ID / VAT-ID ORG
# Amtsgericht Duisburg PERSON
# 0637 09 DATE
# BIC ORG
# HY GPE
# 14 CARDINAL
# Anlagen PERSON
# 1.0 CARDINAL
# 19006153 MONEY
# Kunde Objekt PERSON
# Robeit Bosch PERSON
# Name?_Robert Bosch GmbH PERSON
# 16.25 CARDINAL
# 39006 CARDINAL
# Magedeburg | PLZ FAC
# _ Berlin GPE
# Hersteller PERSON
# Beghelli Anlagentyp PERSON
# _ CARDINAL
# NGBVE ORG
# Durchgefiihrte Arbeiten PERSON
# niOQ Bemerkung WORK_OF_ART
# Sichtkontrolle PERSON
# Oo PERSON
# PrGfeinrichtung x PERSON
# CI Cj FAC
# Ubersichtszeichnung GPE
# xX CI C ORG
# Meldeéinrichtungen PERSON
# Xx PERSON
# Netzbetrieb ORG
# 6 CARDINAL
# Kontrolle der Funktion ORG
# Netziberwachungseinrichtungen PERSON
# Ausfall PERSON
# Ausfail ORG
# Netzversorgung PERSON
# Kontrolie der Ladeeinrichtung PERSON
# Batterieladung GPE
# Konitrolle PERSON
# Liftersteuerung Oo S PERSON
# Kontralle GPE
# Ausdruck PERSON
# Prifungsbuch Ki Oo CO oO PERSON
# Durchftihrung PERSON
# Funktionspriifung xX PERSON
# Durchfihrung PERSON
# Betriebsdauerpriifung QO PERSON
# 1 CARDINAL
# 2 CARDINAL
# 1 CARDINAL
# Ang Jebot PERSON
# Folgetermin nétig PERSON
# Wartung PERSON
# Jal Nein PERSON
# 27119 CARDINAL
# 27 149 CARDINAL
# 1.18 CARDINAL
# Versorgung GPE
# Geschattsfthrer PERSON
# Thomas Buhren PERSON
# Graziano Beghelii gen PERSON
# 46539 CARDINAL
# Dinsiaken Bayer PERSON
# Vereirisbank GPE
# 9701 CARDINAL
# 302 CARDINAL
# 90 CARDINAL
# 364.053 CARDINAL
# 709 CARDINAL
# 02064'9701 CARDINAL
# 0637.09 CARDINAL
# HY GPE
# Amtsgericht Duisburg PERSON
# Batteriepriifprotokoll ORG
# Blockanzahl PERSON
# Ladespannung PERSON
# Durchgefiihrte Arbeiten PERSON
# | Messung t | Messung PERSON
# Sichtkontrolle PERSON
# Batterien GPE
# 1 CARDINAL
# 20 CARDINAL
# | i Sichtkontrolle der Batteriedichtigkeit
# ee
#  WORK_OF_ART
# Sichtkontrolle PERSON
# Jemerkung PERSON
# 4 CARDINAL
# Gelbatterien PERSON
# Batteriesauredichte PERSON
# Pte Sichtpriifung der PERSON
# EC ORG
# 9 CARDINAL
# 108 CARDINAL
# 3 CARDINAL
# zusatzliche Bemerkungen PERSON
# 13,89V DATE
# 2 CARDINAL
# 3 CARDINAL
# 3 CARDINAL
# 36 CARDINAL
# Blockspg ORG
# Soil Min PERSON
# moe ORG
# 2 CARDINAL
# Blockspg ORG
# Soli Max PERSON
# Batterieprifprotokoll ORG
# Batterietyp Batterieschaltung PRODUCT
# Blockspannung Blockanzahi PERSON
# Ladespannung 246V PERSON
# Erhalteladespannung GPE
# Zeitpunkt PERSON
# Sichtkontole der Batren
#
#
#
#
#
#
#
#
#
# | 13,57V WORK_OF_ART
# 19 CARDINAL
# | Bemerkung: WORK_OF_ART
# 2 CARDINAL
# Sichtkontrolle PERSON
# Batteriedichtigkeit GPE
# 2 CARDINAL
# Sichtkontrolle PERSON
# 25 CARDINAL
# || CARDINAL
# 13sev DATE
# asa ORG
# raiav pa | PERSON
# 12,0ev DATE
# a7 | |
#  WORK_OF_ART
# | Po Bemerkung PERSON
# 12,12V WORK_OF_ART
# 28 CARDINAL
# Po Prifung des Batteriesdurestandes ORG
# i36av NORP
# Prasev PERSON
# 2tev CARDINAL
# 2 36av TIME
# rae5v | 72,98v PERSON
# a8 WORK_OF_ART
# | 12,13V PERSON
# GesamtSpg PERSON
# 222,25v CARDINAL
# 218,08v CARDINAL
# 19 CARDINAL
# Blockspg ORG
# Min PERSON
# Blockspg ORG
# Max 14,11V PERSON
# Batterieprifprotokoll PRODUCT
# A92348 ORG
# Blockspannung Blockanzahl PERSON
# 9/9 CARDINAL
# 2is ORDINAL
# Sichtkontrolle PERSON
# Batteriedichtigkeit GPE
# Ladestrom PERSON
# | Messung | PERSON
# 1 CARDINAL
# 19 CARDINAL
# 12,50V CARDINAL
# 1 CARDINAL
# Sichtkontrolle PERSON
# Bemerkung PERSON
# Joerg PERSON
# Batoriesturestandos PERSON
# Joerg Gelbatterien PERSON
# Batorosturedicht GPE
# Gelbatterien PERSON
# Josey PERSON
# 19 DATE
# Po Po Sichtpriifung PERSON
# Warnschilder PERSON
# Blattnummer PERSON
# 108 CARDINAL
# 3 CARDINAL
# 0,00V CARDINAL
# 0,00V CARDINAL
# 3G
# © QUANTITY
# zusatzliche Bemerkungen PERSON
# Ladeteil ORG
# Messungen konnten nicht PERSON
# Max PERSON
# 8 CARDINAL
# 2 CARDINAL
# 5 CARDINAL
# Blockspg ORG
# Batteriepriifprotokoll ORG
# Batteriehersteller Beghelli PERSON
# Durchgefiihrte Arbeiten PERSON
# Sichtkontrolle PERSON
# Batterien GPE
# Sichtkontrolle PERSON
# Sichtkontrolle PERSON
# Ladespannung Erhalteladespannung PERSON
# 12,16V DATE
# 12,26v| DATE
# 6s CARDINAL
# [Tf | fF PERSON
# Sichtkontrolle PERSON
# Bemerkung PERSON
# Gelbatterien PERSON
# Batteriesauredichte PERSON
# Gelbatterien PERSON
# 0,00V CARDINAL
# 23 CARDINAL
# 5 CARDINAL
# 7 CARDINAL
# 2 CARDINAL
# ° PRODUCT
# Zusatzliche Bemerkungen PERSON
# Ladeteil ORG
# Messungen konnten nicht PERSON
# S14 ORG
# 2 CARDINAL
# 2 CARDINAL
# TC ORG
# 4 DATE
# 9 CARDINAL
# 3 CARDINAL
# Wartungsbericht ORG
# Batteriepriifprotokoll ORG
# Erhalteladespannung Entladespannung
#  PERSON
# Bemerkung PERSON
# Sichtkontrolle PERSON
# Batteriedichtigkeit GPE
# 1,30V CARDINAL
# Jnemerkung PERSON
# 8 CARDINAL
# Fritng PERSON
# Battericcaurestandes WORK_OF_ART
# Batioiocdureatnte PERSON
# pao ORG
# Gelbatterien PERSON
# RE Priifung der WORK_OF_ART
# Warnschilder PERSON
# Blattnummer PERSON
# 108 CARDINAL
# 3 CARDINAL
# 0,00V CARDINAL
# Bemerkungen PERSON
# Ladeteil ORG
# Messungen ORG
# konnten nicht PERSON
# werden PERSON
# TD DD Dini PERSON
# QO;rte GPE
# |}]a lala QUANTITY
# S/S GPE
# 4 CARDINAL
# xWartungsbericht GPE
# Batteriepriifprotokoll ORG
# Anlagentyp NGBVA-Z PERSON
# Batterietyp Mepis PERSON
# Ladespannung PERSON
# Ladestrom PERSON
# Seriennummer GPE
# Batteriehersteller Beghelli PERSON
# Batterieschaltung Gruppe FAC
# Blockanzahl PERSON
# Entladespannung GPE
# | Messung 3. PERSON
# Sichtkontrolle PERSON
# Batterien GPE
# 12,43V | ORG
# 5 5 CARDINAL
# 3 CARDINAL
# Sichtkontrolle PERSON
# Batteriedichtigkeit GPE
# Sichtkontrolle PERSON
# Sichtkontrolle PERSON
# Gelbaiterien
#  PERSON
# Batterieraumes
#  PRODUCT
# | Bemerkung PERSON
# Gelbatterien PERSON
# 19 CARDINAL
# Biattnummer PERSON
# 108 CARDINAL
# 3 CARDINAL
# 3 CARDINAL
# 3 CARDINAL
# 0,00V 0,00V QUANTITY
# zusatzliche Bemerkungen PERSON
# 90/46/4616 DATE
# CGT IU ORG
# s/s
# =| PRODUCT
# S/o ORG
# 215 CARDINAL

# %%
# for X in doc.ents:
#     if X.label_=='PERSON':   
#         i=i+1
#         print(i,"-",X.text)

# %%
# i=0
# for X in doc.ents:
#      if X.label_=='PERSON' and not('Bosch' in X.text):
# #         i=i+1
# #         print(i,"-",X.text)
#         doc2=nlp_de(X.text)
#         for Y in doc2.ents:
#              if Y.label_=='PER':
#                 print(Y.text , Y.label_)
# Out:
# Filipchuk PER
# S. Thormeier PER
# Thomas Buhren PER
# Graziano Beghelli PER
# Bayer PER
# Sicuro PER
# Nettowarenwert MwSt PER
# Thomas Buhren PER
# Graziano Beghelli PER
# Bayer PER
# Gesamtsumme PER
# Thomas Buhren PER
# Graziano Beghelli LanterstraBe PER
# Beghelli Anlagentyp PER
# Ang Jebot PER
# Folgetermin PER
# Jal Nein PER
# Thomas Buhren PER
# Graziano Beghelii PER
# Dinsiaken Bayer PER
# Soil Min PER
# Soli Max PER
# Max PER
# Joerg PER
# Joerg Gelbatterien PER
# Po Po Sichtpriifung PER
# Blattnummer PER
# Batteriehersteller Beghelli PER
# Fritng PER
# Blattnummer PER
# Batterietyp Mepis PER
# Batteriehersteller Beghelli PER

# %%
z= 'Bosch' not in X.text

# %%
print(z)
# Out:
# True

# %%
from PyDictionary import PyDictionary as pd

# %%
for X in doc.ents:
     if X.label_=='PERSON' and not('Bosch' in X.text):
#         i=i+1
#         print(i,"-",X.text)
        doc2=nlp_de(X.text)
        for Y in doc2.ents:
             if Y.label_=='PER':
                print(Y.text , Y.label_)
# Out:
# Filipchuk PER
# S. Thormeier PER
# Thomas Buhren PER
# Graziano Beghelli PER
# Bayer PER
# Sicuro PER
# Nettowarenwert MwSt PER
# Thomas Buhren PER
# Graziano Beghelli PER
# Bayer PER
# Gesamtsumme PER
# Thomas Buhren PER
# Graziano Beghelli LanterstraBe PER
# Beghelli Anlagentyp PER
# Ang Jebot PER
# Folgetermin PER
# Jal Nein PER
# Thomas Buhren PER
# Graziano Beghelii PER
# Dinsiaken Bayer PER
# Soil Min PER
# Soli Max PER
# Max PER
# Joerg PER
# Joerg Gelbatterien PER
# Po Po Sichtpriifung PER
# Blattnummer PER
# Batteriehersteller Beghelli PER
# Fritng PER
# Blattnummer PER
# Batterietyp Mepis PER
# Batteriehersteller Beghelli PER

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\jagadesh\Jupyter Projects\OCR\fwusecaseextractnamesfromtext\ger.txt')

# %%
'zytostatisches' in df.AA[2021676]
# Out:
# True

# %%
l1=['a','ab','aab','aaab','bc','cd','de']

# %%
# def binarySearch(arr, x): 
#     l = 0
#     r = len(arr) 
#     while (l <= r): 
#         m = l + ((r - l) // 2) 
  
#         res = (x == arr[m]) 
  
#         # Check if x is present at mid 
#         if (res == 0): 
#             return m - 1
  
#         # If x greater, ignore left half 
#         if (res > 0): 
#             l = m + 1
  
#         # If x is smaller, ignore right half 
#         else: 
#             r = m - 1
  
#     return -1

# %%
2021676/2
# Out:
# 1010838.0

# %%
binarySearch(df.AA,'aagggg')
# Out:
# True

# %%
for X in doc.ents:
     if X.label_=='PERSON' and not('Bosch' in X.text) and binarySearch(df.AA,X.text):
#         i=i+1
#         print(i,"-",X.text)
        doc2=nlp_de(X.text)
        for Y in doc2.ents:
             if Y.label_=='PER':
                print(Y.text , Y.label_)
# Out:
# Reutlingen
#  PER
# Menge Einzelpreis PER
# Steinmiullerallee PER
# HRL-Rt-TM1 PER
# Tag Bemerkung PER
# nhininin PER

# %%
def binarySearch(arr, x):
    for y in arr:
        if x == y:
            return False
        
    return True
