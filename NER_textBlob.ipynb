# %%
from pdf2image import convert_from_path
import pytesseract
from PIL import Image
from collections import Counter
from textblob_de import TextBlobDE as tb

#image_to_string: pytesseract.pytesseract.tesseract_cmd = r'C:\Users\USER\AppData\Local\Tesseract-OCR\tesseract.exe'
#pytesseract.pytesseract.tesseract_cmd = 'C:\Program Files\Tesseract-OCR\tessdata'

#pytesseract.pytesseract.tesseract_cmd = 'C:\Program Files\Tesseract-OCR\tesseract.exe'  # your path may be different
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
pages = convert_from_path(r'C:\Users\jagadesh\Desktop\divyam\a.pdf', 500)

# %%
text=''
for page in pages:
    text = text + (pytesseract.image_to_string(page))

# %%
doc=tb(text)

# %%
doc.sentences
# Out:
# [Sentence("— ENERGIEAG
#
#
#
#  ."), Sentence("Unser Zeichen: | RW/Schg
#  | Telefon: 059000-3727
#  ."), Sentence("Fax: | 059000-53727
#  ‘Energie AG Vertrieb GmbH, B6hmerwaldstr."), Sentence("3, 4020 Linz ."), Sentence("Ort/Datum: Linz, 31.10.2019
#  Herrn, Frau, Firma: Zahibar: Bis zum 30.11.2019
#  Robert Bosch GmbH , ."), Sentence("ohne Abzug
#  Business Unit Connected Mobility."), Sentence("Solutions Steffen Zacharias, CS/PA-
#  Hoferstr."), Sentence("30
#  - 71636 LUDWIGSBURG ; ie
#  DEUTSCHLAND !"), Sentence("os
#  , Mas
#  " Rechnung Nr.: 9190000697 , 4100 4100 1360 15
#  USt-ID-Nummer: DE811128135
#  Vertragskontonummer: 219900000217 re
#  Liefer- bzw. Leistungszeitraum: 01.07.2019 - 30.09.2019 | ee
#  Ubergang der Steuerschuld auf den Leistungsempfanger
#  Menge ME Bezeichnung der Leistung USt."), Sentence("Betrag/Einheit Betrag/EUR
#
#  HUBJECT Roaming Ladevorgange 0 : 54,47
#  Nettobetrag ' mo oO | | 54,47
#  Ust."), Sentence("0 % von 54,47 , 0,00
#
#
#
#  ah Fes
#
#  Fs 3!"), Sentence("B22 PE ay
#  ee
#  aoe
#
#  yA 7 r
#
#  athe oe rr rr
#  i BER SB Be et tg gale © UR:
#  Gesamtbetrag‘
#  fevte cramer onan 3 ten ton
#
#  Fg
#
#  a
#
#  bite’, 8
#  wk
#
#  Zahlbar und klagbar in Linz - Bis zur vollstandigen Bezahlung bleiben die gelieferteh Waren unser uneingeschranktes Eigentum - Bei Zahlungsverzug werden ab dem der Falligkeit folgenden Tag die
#  gesetzlichen Verzugszinsen verrechnet - Beanstandungen finden nur dann Berdcksichtigung, wenn Sie sofort nach Empfang der Ware bzw. sofort nach Fertigstellung der Arbeit erhoben werden - Die
#  Zahlungspflicht wird durch eine eingebrachte Beanstandung nicht aufgehoben."), Sentence("Energie AG Oberdésterreich Vertrieb GmbH - - BOhmerwaldstr."), Sentence("3 + 4020 Linz
#
#  Tel."), Sentence(": +43 (0)5 9000-0 - Fax: 0800 81 8001 « Internet: www.energieag.at » E-Mail: service@energieag.at."), Sentence("Datenschutzerklarung: www.energieag.at/datenschutz-vertrieb - UID: ATU73917719 » FN 502834 m « Landesgericht Linz
#  Raiffeisenlandesbank Oberésterreich - IBAN: AT65 3400 0000 0260 9659 + BIC: RZOOAT2L
#
#  nm
#
#  CM mide me 4 wee Ft© BOSCH
#
#  Von ."), Sentence("° Bearbeiter Telefon Schwieberdingen
#
#  CF/ACR33.4-DE ."), Sentence("31.10.2019
#
#  Empfanger CF/GSA-DE Frau Gesche
#  zk."), Sentence("Rechnungsdokumente zur Digitalisierung
#
#  Guten Tag, -
#
#  bitte scannen Sie die Rechnung(en) ein."), Sentence("Qualifiziertes Vorsortieren ist fur diese Dokumente erforderlich
#
#  0 Ja
#
#  x Nein."), Sentence("Erforderliche Korrekturen, um eine kunftige Bearbeitung im Re-
#  gelprozess zu erméglichen, wurden mit dem/den Lieferanten in die
#  Wege geleitet."), Sentence("Bei den angehangten Dokumenten handelt es sich um Originalrechnungen,
#
#  keine Kopien im Rahmen einer Mahnung."), Sentence("Freundliche GriiBe
#
#  _GS/ACR&3.4-DE Name: Lops a oe
#
#  Seite 1 von 1Kreditoren-Workflow
#
#  Trennblatt Anlagen
#
#  Version 1.0 - Patchcode |Energie AG Vertrieb GmbH
#
#  AT653400000002609659
#  RZOOAT2L
#
#  54,47
#  219900000217
#
#  Offener Betrag
#  Rg.Nr."), Sentence(": 9190000697
#  VkontNr."), Sentence(": 219900000217
#
#
#
#  Energie AG Oberésterreich Vertrieb GmbH
#
#  AT65 3400 0000 0260 9659
#
#  RZQOAT2L 54,47
#  219900000217 ."), Sentence("6112
#
#  Rg.Nr."), Sentence(": 9190000697 | VkontNr."), Sentence(": 219900000217 | DVR:
#  Bei Zahlung via TELEBANKING im Feld ZAHLUNGSREFERENZ bitte die VKontNr."), Sentence(":
#  219900000217 angeben."), Sentence(""Robert Bosch GmbH / Hoferstr."), Sentence("30 / 71636 Ludwigsburg
#
#  + ."), Sentence(": O0000005447< 32+")]

# %%
doc.tokens
# Out:
# WordList(['—', 'ENERGIEAG', '.', 'Unser', 'Zeichen', ':', '|', 'RW/Schg', '|', 'Telefon', ':', '059000-3727', '.', 'Fax', ':', '|', '059000-53727', '‘', 'Energie', 'AG', 'Vertrieb', 'GmbH', ',', 'B6hmerwaldstr', '.', '3', ',', '4020', 'Linz', '.', 'Ort/Datum', ':', 'Linz', ',', '31.10.2019', 'Herrn', ',', 'Frau', ',', 'Firma', ':', 'Zahibar', ':', 'Bis', 'zum', '30.11.2019', 'Robert', 'Bosch', 'GmbH', ',', '.', 'ohne', 'Abzug', 'Business', 'Unit', 'Connected', 'Mobility', '.', 'Solutions', 'Steffen', 'Zacharias', ',', 'CS/PA-', 'Hoferstr', '.', '30', '-', '71636', 'LUDWIGSBURG', ';', 'ie', 'DEUTSCHLAND', '!', 'os', ',', 'Mas', "''", 'Rechnung', 'Nr.', ':', '9190000697', ',', '4100', '4100', '1360', '15', 'USt-ID-Nummer', ':', 'DE811128135', 'Vertragskontonummer', ':', '219900000217', 're', 'Liefer-', 'bzw.', 'Leistungszeitraum', ':', '01.07.2019', '-', '30.09.2019', '|', 'ee', 'Ubergang', 'der', 'Steuerschuld', 'auf', 'den', 'Leistungsempfanger', 'Menge', 'ME', 'Bezeichnung', 'der', 'Leistung', 'USt', '.', 'Betrag/Einheit', 'Betrag/EUR', 'HUBJECT', 'Roaming', 'Ladevorgange', '0', ':', '54,47', 'Nettobetrag', "'", 'mo', 'oO', '|', '|', '54,47', 'Ust', '.', '0', '%', 'von', '54,47', ',', '0,00', 'ah', 'Fes', 'Fs', '3', '!', 'B22', 'PE', 'ay', 'ee', 'aoe', 'yA', '7', 'r', 'athe', 'oe', 'rr', 'rr', 'i', 'BER', 'SB', 'Be', 'et', 'tg', 'gale', '©', 'UR', ':', 'Gesamtbetrag', '‘', 'fevte', 'cramer', 'onan', '3', 'ten', 'ton', 'Fg', 'a', 'bite', '’', ',', '8', 'wk', 'Zahlbar', 'und', 'klagbar', 'in', 'Linz', '-', 'Bis', 'zur', 'vollstandigen', 'Bezahlung', 'bleiben', 'die', 'gelieferteh', 'Waren', 'unser', 'uneingeschranktes', 'Eigentum', '-', 'Bei', 'Zahlungsverzug', 'werden', 'ab', 'dem', 'der', 'Falligkeit', 'folgenden', 'Tag', 'die', 'gesetzlichen', 'Verzugszinsen', 'verrechnet', '-', 'Beanstandungen', 'finden', 'nur', 'dann', 'Berdcksichtigung', ',', 'wenn', 'Sie', 'sofort', 'nach', 'Empfang', 'der', 'Ware', 'bzw.', 'sofort', 'nach', 'Fertigstellung', 'der', 'Arbeit', 'erhoben', 'werden', '-', 'Die', 'Zahlungspflicht', 'wird', 'durch', 'eine', 'eingebrachte', 'Beanstandung', 'nicht', 'aufgehoben', '.', 'Energie', 'AG', 'Oberdésterreich', 'Vertrieb', 'GmbH', '-', '-', 'BOhmerwaldstr', '.', '3', '+', '4020', 'Linz', 'Tel', '.', ':', '+43', '(', '0', ')', '5', '9000-0', '-', 'Fax', ':', '0800', '81', '8001', '«', 'Internet', ':', 'www.energieag.at', '»', 'E-Mail', ':', 'service', '@', 'energieag.at', '.', 'Datenschutzerklarung', ':', 'www.energieag.at/datenschutz-vertrieb', '-', 'UID', ':', 'ATU73917719', '»', 'FN', '502834', 'm', '«', 'Landesgericht', 'Linz', 'Raiffeisenlandesbank', 'Oberésterreich', '-', 'IBAN', ':', 'AT65', '3400', '0000', '0260', '9659', '+', 'BIC', ':', 'RZOOAT2L', 'nm', 'CM', 'mide', 'me', '4', 'wee', 'Ft©', 'BOSCH', 'Von', '.', '°', 'Bearbeiter', 'Telefon', 'Schwieberdingen', 'CF/ACR33.4-DE', '.', '31.10.2019', 'Empfanger', 'CF/GSA-DE', 'Frau', 'Gesche', 'zk', '.', 'Rechnungsdokumente', 'zur', 'Digitalisierung', 'Guten', 'Tag', ',', '-', 'bitte', 'scannen', 'Sie', 'die', 'Rechnung', '(', 'en', ')', 'ein', '.', 'Qualifiziertes', 'Vorsortieren', 'ist', 'fur', 'diese', 'Dokumente', 'erforderlich', '0', 'Ja', 'x', 'Nein', '.', 'Erforderliche', 'Korrekturen', ',', 'um', 'eine', 'kunftige', 'Bearbeitung', 'im', 'Re-', 'gelprozess', 'zu', 'erméglichen', ',', 'wurden', 'mit', 'dem/den', 'Lieferanten', 'in', 'die', 'Wege', 'geleitet', '.', 'Bei', 'den', 'angehangten', 'Dokumenten', 'handelt', 'es', 'sich', 'um', 'Originalrechnungen', ',', 'keine', 'Kopien', 'im', 'Rahmen', 'einer', 'Mahnung', '.', 'Freundliche', 'GriiBe', '_GS/ACR', '&', '3.4-DE', 'Name', ':', 'Lops', 'a', 'oe', 'Seite', '1', 'von', '1Kreditoren-Workflow', 'Trennblatt', 'Anlagen', 'Version', '1.0', '-', 'Patchcode', '|Energie', 'AG', 'Vertrieb', 'GmbH', 'AT653400000002609659', 'RZOOAT2L', '54,47', '219900000217', 'Offener', 'Betrag', 'Rg.Nr', '.', ':', '9190000697', 'VkontNr', '.', ':', '219900000217', 'Energie', 'AG', 'Oberésterreich', 'Vertrieb', 'G ...

# %%
doc.noun_phrases
# Out:
# WordList(['— ENERGIEAG', 'unser Zeichen', '| RW&slash;Schg | Telefon', '| 059000-53727 ‘ Energie AG Vertrieb GmbH', '4020 Linz', '31.10.2019 Herrn', '30.11.2019 Robert Bosch GmbH', 'Abzug Business Unit', 'Steffen Zacharias', '71636 LUDWIGSBURG', 'ie DEUTSCHLAND', "Mas '' Rechnung", '4100 4100 1360 15 USt-ID-Nummer', 'DE811128135 Vertragskontonummer', '219900000217 re', '30.09.2019 | ee Ubergang', 'den Leistungsempfanger Menge ME Bezeichnung', 'Leistung USt', 'betrag&slash;einheit Betrag&slash;EUR HUBJECT', "54,47 Nettobetrag ' mo oO | |", '0 %', 'Fes Fs', 'b22 PE ay ee aoe yA', 'athe oe rr rr i BER SB Be et tg gale © UR', 'Gesamtbetrag ‘ fevte cramer onan 3 ten ton Fg a bite ’', '8 wk', 'vollstandigen Bezahlung', 'gelieferteh Waren unser uneingeschranktes Eigentum', 'Falligkeit folgenden Tag die gesetzlichen Verzugszinsen', 'Die Zahlungspflicht', 'eingebrachte Beanstandung', 'Energie AG', '3 + 4020 Linz Tel', '0800 81 8001 « Internet', 'www.energieag.at » E-Mail', 'service @ energieag.at', 'ATU73917719 » FN 502834 m « Landesgericht Linz', 'AT65 3400 0000 0260 9659 + BIC', 'RZOOAT2L nm CM mide me 4 wee Ft© BOSCH', '° Bearbeiter Telefon Schwieberdingen CF&slash;ACR33.4-DE', '31.10.2019 Empfanger CF&slash;GSA-DE Frau Gesche zk', 'Digitalisierung Guten Tag', 'Sie die Rechnung', 'qualifiziertes Vorsortieren', 'diese Dokumente', '0 Ja x Nein', 'erforderliche Korrekturen', 'kunftige Bearbeitung', 'dem&slash;den Lieferanten', 'den angehangten Dokumenten', 'keine Kopien', 'Rahmen einer Mahnung', 'freundliche GriiBe _GS&slash;ACR & 3.4-DE Name', 'Lops a oe Seite', '1Kreditoren-Workflow Trennblatt Anlagen Version', 'Patchcode |Energie AG Vertrieb GmbH AT653400000002609659 RZOOAT2L 54,47 219900000217 Offener Betrag Rg.Nr', '9190000697 VkontNr', '219900000217 Energie AG', 'GmbH AT65 3400 0000 0260 9659 RZQOAT2L', '6112 Rg.Nr', '9190000697 | VkontNr', '219900000217 | DVR', 'Feld ZAHLUNGSREFERENZ', '`` Robert Bosch GmbH &slash; Hoferstr', '30 &slash; 71636 Ludwigsburg +'])

# %%
doc.tags
# Out:
# [('—', 'JJ'),
#  ('ENERGIEAG', 'NN'),
#  ('Unser', 'PRP$'),
#  ('Zeichen', 'NN'),
#  ('|', 'NN'),
#  ('RW/Schg', 'NN'),
#  ('|', 'NN'),
#  ('Telefon', 'NN'),
#  ('059000-3727', 'CD'),
#  ('Fax', 'NN'),
#  ('|', 'NN'),
#  ('059000-53727', 'CD'),
#  ('‘', 'NN'),
#  ('Energie', 'NN'),
#  ('AG', 'NNP'),
#  ('Vertrieb', 'NNP'),
#  ('GmbH', 'NNP'),
#  ('B6hmerwaldstr', 'NN'),
#  ('3', 'CD'),
#  ('4020', 'CD'),
#  ('Linz', 'NN'),
#  ('Ort/Datum', 'NN'),
#  ('Linz', 'NN'),
#  ('31.10.2019', 'CD'),
#  ('Herrn', 'NN'),
#  ('Frau', 'NN'),
#  ('Firma', 'NN'),
#  ('Zahibar', 'JJ'),
#  ('Bis', 'IN'),
#  ('zum', 'IN'),
#  ('30.11.2019', 'CD'),
#  ('Robert', 'NNP'),
#  ('Bosch', 'NNP'),
#  ('GmbH', 'NNP'),
#  ('ohne', 'IN'),
#  ('Abzug', 'NNP'),
#  ('Business', 'NNP'),
#  ('Unit', 'NNP'),
#  ('Connected', 'FW'),
#  ('Mobility', 'FW'),
#  ('Solutions', 'FW'),
#  ('Steffen', 'NNP'),
#  ('Zacharias', 'NNP'),
#  ('CS/PA-', 'TRUNC'),
#  ('Hoferstr', 'NN'),
#  ('30', 'CD'),
#  ('71636', 'CD'),
#  ('LUDWIGSBURG', 'NN'),
#  ('ie', 'PRP'),
#  ('DEUTSCHLAND', 'NN'),
#  ('os', 'NN'),
#  ('Mas', 'NN'),
#  ("''", 'NNP'),
#  ('Rechnung', 'NNP'),
#  ('Nr.', 'VB'),
#  ('9190000697', 'CD'),
#  ('4100', 'CD'),
#  ('4100', 'CD'),
#  ('1360', 'CD'),
#  ('15', 'CD'),
#  ('USt-ID-Nummer', 'NN'),
#  ('DE811128135', 'NN'),
#  ('Vertragskontonummer', 'NN'),
#  ('219900000217', 'CD'),
#  ('re', 'NN'),
#  ('Liefer-', 'TRUNC'),
#  ('bzw.', 'CC'),
#  ('Leistungszeitraum', 'NN'),
#  ('01.07.2019', 'CD'),
#  ('30.09.2019', 'CD'),
#  ('|', 'NN'),
#  ('ee', 'NN'),
#  ('Ubergang', 'NN'),
#  ('der', 'DT'),
#  ('Steuerschuld', 'NN'),
#  ('auf', 'IN'),
#  ('den', 'DT'),
#  ('Leistungsempfanger', 'NN'),
#  ('Menge', 'NN'),
#  ('ME', 'NN'),
#  ('Bezeichnung', 'NN'),
#  ('der', 'DT'),
#  ('Leistung', 'JJ'),
#  ('USt', 'NN'),
#  ('Betrag/Einheit', 'NN'),
#  ('Betrag/EUR', 'NN'),
#  ('HUBJECT', 'NNP'),
#  ('Roaming', 'FW'),
#  ('Ladevorgange', 'FW'),
#  ('0', 'CD'),
#  ('54,47', 'CD'),
#  ('Nettobetrag', 'NN'),
#  ("'", 'NN'),
#  ('mo', 'NN'),
#  ('oO', 'NNP'),
#  ('|', 'NNP'),
#  ('|', 'NNP'),
#  ('54,47', 'CD'),
#  ('Ust', 'RP'),
#  ('0', 'CD'),
#  ('%', 'NN'),
#  ('von', 'IN'),
#  ('54,47', 'CD'),
#  ('0,00', 'CD'),
#  ('ah', 'UH'),
#  ('Fes', 'NN'),
#  ('Fs', 'NN'),
#  ('3', 'CD'),
#  ('B22', 'NN'),
#  ('PE', 'NN'),
#  ('ay', 'NNP'),
#  ('ee', 'NNP'),
#  ('aoe', 'NNP'),
#  ('yA', 'NNP'),
#  ('7', 'CD'),
#  ('r', 'IN'),
#  ('athe', 'NN'),
#  ('oe', 'NN'),
#  ('rr', 'NN'),
#  ('rr', 'NN'),
#  ('i', 'NN'),
#  ('BER', 'NN'),
#  ('SB', 'PRP$'),
#  ('Be', 'NN'),
#  ('et', 'NN'),
#  ('tg', 'NN'),
#  ('gale', 'NN'),
#  ('©', 'NN'),
#  ('UR', 'NN'),
#  ('Gesamtbetrag', 'NN'),
#  ('‘', 'NN'),
#  ('fevte', 'NN'),
#  ('cramer', 'NN'),
#  ('onan', 'NN'),
#  ('3', 'CD'),
#  ('ten', 'NN'),
#  ('ton', 'NN'),
#  ('Fg', 'NN'),
#  ('a', 'PRP'),
#  ('bite', 'NN'),
#  ('’', 'NN'),
#  ('8', 'CD'),
#  ('wk', 'NN'),
#  ('Zahlbar', 'JJ'),
#  ('und', 'CC'),
#  ('klagbar', 'JJ'),
#  ('in', 'IN'),
#  ('Linz', 'NN'),
#  ('Bis', 'IN'),
#  ('zur', 'IN'),
#  ('vollstandigen', 'NN'),
#  ('Bezahlung', 'NN'),
#  ('bleiben', 'VB'),
#  ('die', 'DT'),
#  ('gelieferteh', 'NN'),
#  ('Waren', 'NNS'),
#  ('unser', 'PRP$'),
#  ('uneingeschranktes', 'NN'),
#  ('Eigentum', 'NN'),
#  ('Bei', 'IN'),
#  ('Zahlungsverzug', 'NN'),
#  ('werden', 'VB'),
#  ('ab', 'IN'),
#  ('dem', 'WDT'),
#  ('der', 'DT'),
#  ('Falligkeit', 'NN'),
#  ('folgenden', 'JJ'),
#  ('Tag', 'NN'),
#  ('die', 'DT'),
#  ('gesetzlichen', 'JJ'),
#  ('Verzugszinsen', 'NN'),
#  ('verrechnet', 'VB'),
#  ('Beanstandungen', 'NN'),
#  ('finden', 'VB'),
#  ('nur', 'RB'),
#  ('dann', 'IN'),
#  ('Berdcksichtigung', 'NN'),
#  ('wenn', 'IN'),
#  ('Sie', 'JJ'),
#  ('sofort', 'RB'),
#  ('nach', 'IN'),
#  ('Empfang', 'NN'),
#  ('der', 'DT'),
#  ('Ware', 'NN'),
#  ('bzw.', 'RB'),
#  ('sofort', 'RB'),
#  ('nach', 'IN'),
#  ('Fertigstellung', 'NN'),
#  ('der', 'DT'),
#  ('Arbeit', 'NN'),
#  ('erhoben', 'VBN'),
#  ('werden', 'VB'),
#  ('Die', 'DT'),
#  ('Zahlungspflicht', 'NN'),
#  ('wird', 'VB'),
#  ('durch', 'IN'),
#  ('eine', 'DT'),
#  ('eingebrachte', 'JJ'),
#  ('Beanstandung', 'NN'),
#  ('nicht', 'RB'),
#  ('aufgehoben', 'RP'),
#  ('Energie', 'NN'),
#  ('AG', 'NNP'),
#  ('Oberdésterreich', 'FW'),
#  ('Vertrieb', 'FW'),
#  ('GmbH', 'NNP'),
#  ('BOhmerwaldstr', 'NN'),
#  ('3', 'CD'),
#  ('+', 'NN'),
#  ('4020', 'CD'),
#  ('Linz', 'JJ'),
#  ('Tel', 'NN'),
#  ('+43', 'NN'),
#  ('0', 'CD'),
#  ('5', 'CD'),
#  ('9000-0', 'CD'),
#  ('Fax', 'NN'),
#  ('0800', 'CD'),
#  ('81', 'CD'),
#  ('8001', 'CD'),
#  ('«', 'NN'),
#  ('Internet', 'NN'),
#  ('www.energieag.at', 'NN'),
#  ('»', 'NN'),
#  ('E-Mail', 'NN'),
#  ('service', 'NN'),
#  ('@', 'JJ'),
#  ('energieag.at', 'NN'),
#  ('Datenschutzerklarung', 'NN'),
#  ('www.energieag.at/datenschutz-vertrieb', 'NN'),
#  ('UID', 'NN'),
#  ('ATU73917719', 'NN'),
#  ('»', 'NN'),
#  ('FN', 'NN'),
#  ('502834', 'CD'),
#  ('m', 'NN'),
#  ('«', 'NN'),
#  ('Landesgericht', 'NN'),
#  ('Linz', 'NN'),
#  ('Raiffeisenlandesbank', 'FW'),
#  ('Oberésterreich', 'FW'),
#  ('IBAN', 'NN'),
#  ('AT65', 'NN'),
#  ('3400', 'CD'),
#  ('0000', 'CD'),
#  ('0260', 'CD'),
#  ('9659', 'CD'),
#  ('+', 'NN'),
#  ('BIC', 'NN'),
#  ('RZOOAT2L', 'NN'),
#  ('nm', 'NN'),
#  ('CM', 'NN'),
#  ('mide', 'NN'),
#  ('me', 'NN'),
#  ('4', 'CD'),
#  ('wee', 'NN'),
#  ('Ft©', 'NN'),
#  ('BOSCH', 'NNP'),
#  ('Von', 'RP'),
#  ('°', 'NN'),
#  ('Bearbeiter', 'NN'),
#  ('Telefon', 'NN'),
#  ('Schwieberdingen', 'JJ'),
#  ('CF/ACR33.4-DE', 'NN'),
#  ('31.10.2019', 'CD'),
#  ('Empfanger', 'NN'),
#  ('CF/GSA-DE', 'NN'),
#  ('Frau', 'NN'),
#  ('Gesche', 'JJ'),
#  ('zk', 'NN'),
#  ('Rechnungsdokumente', 'NN'),
#  ('zur', 'IN'),
#  ('Digitalisierung', 'NN'),
#  ('Guten', 'NN'),
#  ('Tag', 'NN'),
#  ('bitte', 'VB'),
#  ('scannen', 'VB'),
#  ('Sie', 'PRP'),
#  ('die', 'DT'),
#  ('Rechnung', 'NN'),
#  ('en', 'PRP'),
#  ('ein', 'RP'),
#  ('Qualifiziertes', 'NN'),
#  ('Vorsortieren', 'NN'),
#  ('ist', 'VB'),
#  ('fur', 'RB'),
#  ('diese', 'DT'),
#  ('Dokumente', 'NN'),
#  ('erforderlich', 'JJ'),
#  ('0', 'CD'),
#  ('Ja', 'NN'),
#  ('x', 'JJ'),
#  ('Nein', 'NN'),
#  ('Erforderliche', 'JJ'),
#  ('Korrekturen', 'NN'),
#  ('um', 'IN'),
#  ('eine', 'DT'),
#  ('kunftige', 'NN'),
#  ('Bearbeitung', 'NN'),
#  ('im', 'IN'),
#  ('Re-', 'TRUNC'),
#  ('gelprozess', 'NN'),
#  ('zu', 'IN'),
#  ('erméglichen', 'VB'),
#  ('wurden', 'VB'),
#  ('mit', 'IN'),
#  ('dem/den', 'JJ'),
#  ('Lieferanten', 'NN'),
#  ('in', 'IN'),
#  ('die', 'DT'),
#  ('Wege', 'NN'),
#  ('geleitet', 'RP'),
#  ('Bei', 'IN'),
#  ('den', 'DT'),
#  ('angehangten', 'NN'),
#  ('Dokumenten', 'NN'),
#  ('handelt', 'VB'),
#  ('es', 'PRP'),
#  ('sich', 'PRP'),
#  ('um', 'IN'),
#  ('Originalrechnungen', 'NN'),
#  ('keine', 'JJ'),
#  ('Kopien', 'NN'),
#  ('im', 'IN'),
#  ('Rahmen', 'NN'),
#  ('einer', 'DT'),
#  ('Mahnung', 'NN'),
#  ('Freundliche', 'NN'),
#  ('GriiBe', 'NN'),
#  ('_GS/ACR', 'NN'),
#  ('&', 'NN'),
#  ('3.4-DE', 'NN'),
#  ('Name', 'NN'),
#  ('Lops', 'NN'),
#  ('a', 'PRP'),
#  ('oe', 'NN'),
#  ('Seite', 'NN'),
#  ('1', 'CD'),
#  ('von', 'IN'),
#  ('1Kreditoren-Workflow', 'NN'),
#  ('Trennblatt', 'NN'),
#  ('Anlagen', 'NN'),
#  ('Version', 'NN'),
#  ('1.0', 'CD'),
#  ('Patchcode', 'NN'),
#  ('|Energie', 'NN'),
#  ('AG', 'NNP'),
#  ('Vertrieb', 'NNP'),
#  ('GmbH', 'NNP'),
#  ('AT653400000002609659', 'NNP'),
#  ('RZOOAT2L', 'NNP'),
#  ('54,47', 'CD'),
#  ('219900000217', 'CD'),
#  ('Offener', 'NNP'),
#  ('Betrag', 'JJ'),
#  ('Rg.Nr', 'NN'),
#  ('9190000697', 'CD'),
#  ('VkontNr', 'NN'),
#  ('219900000217', 'CD'),
#  ('Energie', 'NN'),
#  ('AG', 'NNP'),
#  ('Oberésterreich', 'FW'),
#  ('Vertrieb', 'FW'),
#  ('GmbH', 'NNP'),
#  ('AT65', 'NNP'),
#  ('3400', 'CD'),
#  ('0000', 'CD'),
#  ('0260', 'CD'),
#  ('9659', 'CD'),
#  ('RZQOAT2L', 'NN'),
#  ('54,47', 'CD'),
#  ('219900000217', 'CD'),
#  ('6112', 'CD'),
#  ('Rg.Nr', 'NN'),
#  ('9190000697', 'CD'),
#  ('|', 'JJ'),
#  ('VkontNr', 'NN'),
#  ('219900000217', 'CD'),
#  ('|', 'NN'),
#  ('DVR', 'NN'),
#  ('Bei', 'IN'),
#  ('Zahlung', 'NN'),
#  ('via', 'IN'),
#  ('TELEBANKING', 'NN'),
#  ('im', 'IN'),
#  ('Feld', 'NN'),
#  ('ZAHLUNGSREFERENZ', 'NNP'),
#  ('bitte', 'VB'),
#  ('die', 'DT'),
#  ('VKontNr', 'NN'),
#  ('219900000217', 'CD'),
#  ('angeben', 'VB'),
#  ('``', 'NN'),
#  ('Robert', 'NNP'),
#  ('Bosch', 'NNP'),
#  ('GmbH', 'NNP'),
#  ('/', 'CC'),
#  ('Hoferstr', 'NNP'),
#  ('30', 'CD'),
#  ('/', 'CC'),
#  ('71636', 'CD'),
#  ('Ludwigsburg', 'NNP'),
#  ('+', 'NNP'),
#  ('O0000005447', 'NN'),
#  ('<', 'SYM'),
#  ('32+', 'NN')]
