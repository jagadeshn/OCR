# %%
from pdf2image import convert_from_path
import pytesseract
from PIL import Image
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
import de_core_news_sm
#spacy.load('de_core_news_sm')
nlp = spacy.load('de_core_news_sm')
nlp1 = en_core_web_sm.load()
#image_to_string: pytesseract.pytesseract.tesseract_cmd = r'C:\Users\USER\AppData\Local\Tesseract-OCR\tesseract.exe'
#pytesseract.pytesseract.tesseract_cmd = 'C:\Program Files\Tesseract-OCR\tessdata'

#pytesseract.pytesseract.tesseract_cmd = 'C:\Program Files\Tesseract-OCR\tesseract.exe'  # your path may be different
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
pages = convert_from_path(r'C:\Users\jagadesh\Desktop\divyam\a.pdf', 500)

# %%
text=''
for page in pages:
    text = text + (pytesseract.image_to_string(page))
    #doc1= nlp1("Description Bastian Schweinsteiger is a German retired professional footballer who usually played as central midfielder. Earlier in his career, he primarily played as a wide midfielder. He spent 17 seasons at Bayern Munich, playing in exactly 500 matches across all")
    #doc = nlp("Description Bastian Schweinsteiger is a German retired professional footballer who usually played as central midfielder. Earlier in his career, he primarily played as a wide midfielder. He spent 17 seasons at Bayern Munich, playing in exactly 500 matches across all")
    #print (text)
print(text)
# Out:
# — ENERGIEAG
#
#
#
# . Unser Zeichen: | RW/Schg
# | Telefon: 059000-3727
# . Fax: | 059000-53727
# ‘Energie AG Vertrieb GmbH, B6hmerwaldstr. 3, 4020 Linz . Ort/Datum: Linz, 31.10.2019
# Herrn, Frau, Firma: Zahibar: Bis zum 30.11.2019
# Robert Bosch GmbH , . ohne Abzug
# Business Unit Connected Mobility.
# Solutions Steffen Zacharias, CS/PA-
# Hoferstr. 30
# - 71636 LUDWIGSBURG ; ie
# DEUTSCHLAND ! os
# , Mas
# " Rechnung Nr.: 9190000697 , 4100 4100 1360 15
# USt-ID-Nummer: DE811128135
# Vertragskontonummer: 219900000217 re
# Liefer- bzw. Leistungszeitraum: 01.07.2019 - 30.09.2019 | ee
# Ubergang der Steuerschuld auf den Leistungsempfanger
# Menge ME Bezeichnung der Leistung USt. Betrag/Einheit Betrag/EUR
#
# HUBJECT Roaming Ladevorgange 0 : 54,47
# Nettobetrag ' mo oO | | 54,47
# Ust. 0 % von 54,47 , 0,00
#
#
#
# ah Fes
#
# Fs 3!
#
# B22 PE ay
# ee
# aoe
#
# yA 7 r
#
# athe oe rr rr
# i BER SB Be et tg gale © UR:
# Gesamtbetrag‘
# fevte cramer onan 3 ten ton
#
# Fg
#
# a
#
# bite’, 8
# ...

# %%
doc=nlp1(text)

# %%
i=0
j=0
for X in doc.ents:
    print(i,"-",X.text)

    if X.label_=='PERSON':   
        doc2=nlp(X.text)
        i=i+1
#         for Y in doc2.ents:
#             print(i-1, j)
#             j=j+1
#             if Y.label_=='PER':
#                 print(X.text, X.label_)
# Out:
# 0 - Energie AG Vertrieb
# 0 - 54,47
# 0 - 219900000217
# 0 - 9190000697
# 0 - VkontNr
# 0 - 219900000217
# 0 - Energie AG Oberésterreich Vertrieb GmbH
# 0 - 3400
# 0 - 0260 9659
# 0 - 54,47
# 0 - 219900000217
# 0 - 6112
# 0 - 9190000697
# 0 - 219900000217
# 0 - Bei Zahlung
# 0 - TELEBANKING
# 0 - 219900000217
# 0 - Robert Bosch GmbH / Hoferstr
# 1 - 30 / 71636
# 1 - Ludwigsburg
# 1 - 32
# 1 - Energie AG Vertrieb GmbH
# 1 - 4020
# 1 - Linz
# 1 - Frau
# 1 - Firma
# 2 - Robert Bosch GmbH
# 3 - Solutions
# 3 - Steffen Zacharias
# 4 - Hoferstr
# 5 - 30
# 5 - 71636
# 5 - Mas
# 6 - 9190000697
# 6 - 4100 4100 1360 15
# 6 - 219900000217
# 6 - Betrag/Einheit Betrag/EUR
# 6 - 54,47
# 6 - 54,47
# 6 - 0 %
# 6 - 54,47
# 6 - B22 PE
# 6 - 7
# 6 - onan
# 6 - 3 ten ton
# 6 - 8
# 6 - Zahlbar
# 6 - Linz - Bis
# 6 - Bezahlung bleiben
# 7 - Waren
# 8 - Eigentum - Bei Zahlungsverzug
# 8 - Sie
# 8 - Empfang
# 9 - Fertigstellung
# 10 - Arbeit
# 10 - Zahlungspflicht
# 11 - Beanstandung nicht aufgehoben
# ...

# %%
type(X)
# Out:
# spacy.tokens.span.Span

# %%
nlp = spacy.load('de_core_news_sm')
#import de_core_news_sm
#spacy.load('de_core_news_sm')
#nlp = de_core_web_sm.load()

# %%
doc=nlp1("""Robert Bosch GmbH , . ohne Abzug
.
Steffen Zacharias, CS/PA-
Hoferstr. 30 - 71636 LUDWIGSBURG ; ie DEUTSCHLAND ! os""")

# %%
for X in doc.ents:
    #if X.label_=='PER':
    
        print(X.text, X.label_)
# Out:
# Robert Bosch GmbH PERSON
# Abzug GPE
# Steffen Zacharias PERSON
# CS/PA-
#  ORG
# Hoferstr PERSON
# 30 - 71636 DATE
